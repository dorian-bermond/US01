# %%
1+1
# Out:
# 2

# %%
import pandas as pd

# %%
pd.read('/home/triviiz/Documents/Cours/US01/2019-US01-Data-Science-master/Data-sheet-STUDENTS.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-ec3dc6a3422b> in <module>
# ----> 1 pd.read('/home/triviiz/Documents/Cours/US01/2019-US01-Data-Science-master/Data-sheet-STUDENTS.xlsx')
#
# /usr/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
pd.read_excel('/home/triviiz/Documents/Cours/US01/2019-US01-Data-Science-master/Data-sheet-STUDENTS.xlsx')
# Out:
#    Unnamed: 0                         Indicator #                Unnamed: 2  \
# 0   Country #                       Source link:                        NaN
# 1         NaN      Country (according to CN Gov):  Date of research inquiry
# 2           1                         Afghanistan                       NaN
# 3           2                             Albania                       NaN
# 4           3                             Armenia                       NaN
# ..        ...                                 ...                       ...
# 65         64  United States of America (Not BRI)                       NaN
# 66         65                             Ukraine                       NaN
# 67         66                          Uzbekistan                       NaN
# 68         67                             Vietnam                       NaN
# 69         68                               Yemen                       NaN
#
#                                               1  \
# ...

# %%
pd.read_excel('/home/triviiz/Documents/Cours/US01/2019-US01-Data-Science-master/Data-sheet-STUDENTS.xlsx', index_col = 2)
# Out:
#                          Unnamed: 0                         Indicator #  \
# NaN                       Country #                       Source link:
# Date of research inquiry        NaN      Country (according to CN Gov):
# NaN                               1                         Afghanistan
# NaN                               2                             Albania
# NaN                               3                             Armenia
# ...                             ...                                 ...
# NaN                              64  United States of America (Not BRI)
# NaN                              65                             Ukraine
# NaN                              66                          Uzbekistan
# NaN                              67                             Vietnam
# NaN                              68                               Yemen
#
#                                                                     1  \
# ...

# %%
pd.read_excel('/home/triviiz/Documents/Cours/US01/2019-US01-Data-Science-master/Data-sheet-STUDENTS.xlsx', header = 2, index_col = 0)
# Out:
#         Country (according to CN Gov): Date of research inquiry  \
# 1                          Afghanistan                      NaT
# 2                              Albania                      NaT
# 3                              Armenia                      NaT
# 4                           Azerbaijan                      NaT
# 5                              Bahrain                      NaT
# ..                                 ...                      ...
# 64  United States of America (Not BRI)                      NaT
# 65                             Ukraine                      NaT
# 66                          Uzbekistan                      NaT
# 67                             Vietnam                      NaT
# 68                               Yemen                      NaT
#
#     HF Index of Economic Freedom (Scale: 1-100)  \
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# ...

# %%
dtfrm = pd.read_excel('/home/triviiz/Documents/Cours/US01/2019-US01-Data-Science-master/Data-sheet-STUDENTS.xlsx', header = 2, index_col = 0)

# %%
dtfrm
# Out:
#         Country (according to CN Gov): Date of research inquiry  \
# 1                          Afghanistan                      NaT
# 2                              Albania                      NaT
# 3                              Armenia                      NaT
# 4                           Azerbaijan                      NaT
# 5                              Bahrain                      NaT
# ..                                 ...                      ...
# 64  United States of America (Not BRI)                      NaT
# 65                             Ukraine                      NaT
# 66                          Uzbekistan                      NaT
# 67                             Vietnam                      NaT
# 68                               Yemen                      NaT
#
#     HF Index of Economic Freedom (Scale: 1-100)  \
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# ...

# %%
dtfrm(column = 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-739cb2cb4d94> in <module>
# ----> 1 dtfrm(column = 2)
#
# TypeError: 'DataFrame' object is not callable

# %%
dtfrm[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-2b68f72be71a> in <module>
# ----> 1 dtfrm[0]
#
# ...

# %%
dtfrm
# Out:
#         Country (according to CN Gov): Date of research inquiry  \
# 1                          Afghanistan                      NaT
# 2                              Albania                      NaT
# 3                              Armenia                      NaT
# 4                           Azerbaijan                      NaT
# 5                              Bahrain                      NaT
# ..                                 ...                      ...
# 64  United States of America (Not BRI)                      NaT
# 65                             Ukraine                      NaT
# 66                          Uzbekistan                      NaT
# 67                             Vietnam                      NaT
# 68                               Yemen                      NaT
#
#     HF Index of Economic Freedom (Scale: 1-100)  \
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# ...

# %%
dtfrm["Country"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-6eee9ce0080c> in <module>
# ----> 1 dtfrm["Country"]
#
# ...

# %%
dtrm["Country (according to CN Gov):"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c1fb74a23d7e> in <module>
# ----> 1 dtrm["Country (according to CN Gov):"]
#
# NameError: name 'dtrm' is not defined

# %%
dtfrm["Country (according to CN Gov):"]
# Out:
# 1                            Afghanistan
# 2                                Albania
# 3                                Armenia
# 4                             Azerbaijan
# 5                                Bahrain
#                      ...
# 64    United States of America (Not BRI)
# 65                               Ukraine
# 66                            Uzbekistan
# 67                               Vietnam
# 68                                 Yemen
# Name: Country (according to CN Gov):, Length: 68, dtype: object

# %%
df = pd.read_excel('/home/triviiz/Documents/Cours/US01/2019-US01-Data-Science-master/Data-sheet-STUDENTS.xlsx', header = 2, index_col = 0)

# %%
df[Albania]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-40513ed46b25> in <module>
# ----> 1 df[Albania]
#
# NameError: name 'Albania' is not defined
